# %% [markdown]
# <a href="https://colab.research.google.com/github/josel26449-beep/selecao_alura/blob/main/codigo_receita_bolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import time # Biblioteca para simular o tempo passado

# %%
print("--- INICIANDO O ALGORITIMO DO BOLO ---")
# Out:
# --- INICIANDO O ALGORITIMO DO BOLO ---

# %%
# 1. Variaveis: Separando os ingredientes e ferramentas
temperatura_forno = 0
forma_untada = True
tigela = [] # Uma lista vazia para colocar os ingredientes
massa_homogenea = False
tempo_de_forno = 40
palito_limpo = False
