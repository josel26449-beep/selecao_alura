# %% [markdown]
# <a href="https://colab.research.google.com/github/josel26449-beep/selecao_alura/blob/main/Damos_lhe_as_boas_vindas_ao_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # Centro de Educação Tecnológica do Amazonas
#
#  # Manaus, 17 de março de 2026

# %%
import time
print(time.ctime())
# Out:
# Tue Mar 17 18:48:07 2026

# %%
s = 1
time.sleep(s)
print (time.ctime())
# Out:
# Tue Mar 17 18:50:15 2026

# %%
print("Hello word")
# Out:
# Hello word

# %% [markdown]
# O texto pode ficar em **negrito**
#
# O texto também pode ficar em *texto em italico*
#
# ou mesmo com a fonte ~~riscada~~

# %% [markdown]
# $\sqrt{3x-1}+(1+x)^2$

# %% [markdown]
# $e^x=\sum_{i=0}infty \frac{1}{i!}xî$
